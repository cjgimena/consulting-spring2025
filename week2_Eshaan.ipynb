# %% [markdown]
# ## Week 2: Jupyter Notebook - Pandas Introduction/Overview
# Make sure to select your Kernel before starting!
#
# Watch the [Youtube Video](https://www.youtube.com/watch?v=DkjCaAMBGWM&t=1s) I based this notebook from!

# %% [markdown]
# ### Import Pandas Library/Package
# `import pandas as pd`

# %%
import pandas as pd

# %% [markdown]
# ### Optional: Displaying your Dataframe
# Don't use for big datasets

# %%
pd.set_option("display.max_columns", None)  # Show all columns
pd.set_option("display.max_rows", None)     # Show all rows

# %% [markdown]
# ### How to make a dataframe
# `pd.DataFrame()`

# %%
data = {'Name': ['Zophie', 'Alice', 'Bob', 'Charlie'], 
        'Age': [7, 5, 3, 2],
        'Color': ['Gray', 'Black', 'Brown', 'White']
        }  

data                                                     # Called a Python Dictionary
# Out:
# {'Name': ['Zophie', 'Alice', 'Bob', 'Charlie'],
#  'Age': [7, 5, 3, 2],
#  'Color': ['Gray', 'Black', 'Brown', 'White']}

# %% [markdown]
# #### Create a data frame
# Store the dataframe using the `pd.DataFrame()` function into a variable called `df`

# %%
df = pd.DataFrame(data)
df
# Out:
#       Name  Age  Color
# 0   Zophie    7   Gray
# 1    Alice    5  Black
# 2      Bob    3  Brown
# 3  Charlie    2  White

# %% [markdown]
# ### Read In Datasets
# `pd.read_csv()`
# Read in the file from the data folder called `Shot_Visuals_KaylanBigun_NathanTrouve.csv`
#
# Save as `shots`

# %%
shots = pd.read_csv("data/Shot_Visuals_KaylanBigun_NathanTrouve.csv")

# %% [markdown]
# `pd.read_json()`

# %% [markdown]
# `pd.read_excel(x, sheet_name)`

# %%
shots_excel = pd.read_excel('data/(playsight)kaylan_usc.xlsx', sheet_name='Points')
# Out:
#      Point  Game  Set Serve State Match Server  Host Game Score  \
# 0        1     1    1      second         host                0
# 1        2     1    1      second         host                0
# 2        3     1    1       first         host                0
# 3        4     1    1      second         host                0
# 4        5     2    1      second        guest                0
# 5        6     2    1      second        guest               15
# 6        7     2    1       first        guest               30
# 7        8     2    1      second        guest               40
# 8        9     3    1       first         host                0
# 9       10     3    1       first         host                0
# 10      11     3    1      second         host                0
# 11      12     3    1      second         host               15
# 12      13     3    1      second         host               15
# 13      14     3    1      second         host               30
# 14      15     3    1       first         host               40
# 15      16     4    1       first        guest                0
# 16      17     4    1       first        guest                0
# 17      18     4    1       first        guest                0
# 18      19     4    1      second        guest               15
# 19      20     4    1      second        guest               30
# 20      21     4    1      second        guest               30
# 21      22     4    1       first        guest               40
# 22      23     5    1      second         host                0
# 23      24     5    1       first         host               15
# 24      25     5    1      second         host               30
# 25      26     5    1       first         host               30
# 26      27     5    1      second         host               40
# 27      28     5    1       first         host               40
# 28      29     5    1      second         host               40
# 29      30     6    1       first        guest                0
# 30      31     6    1       first        guest               15
# 31      32     6    1       first        guest               15
# 32      33     6    1       first        guest               15
# 33      34     6    1      second        guest               30
# 34      35     6    1       first        guest               40
# 35      36     6    1      second        guest               40
# 36      37     7    1       first         host                0
# 37      38     7    1      second         host               15
# 38      39     7    1       first         host               30
# 39      40     7    1       first         host               30
# 40      41     7    1       first         host               30
# 41      42     7    1       first         host               30
# 42      43     7    1      second         host               40
# 43      44     8    1       first        guest                0
# 44      45     8    1       first        guest                0
# 45      46     8    1       first        guest                0
# 46      47     8    1       first        guest                0
# 47      48     9    1      second         host                0
# 48      49     9    1       first         host                0
# 49      50     9    1       first         host               15
# 50      51     9    1       first         host               15
# 51      52     9    1       first         host               15
# 52      53    10    1      second        guest                0
# 53      54    10    1      second        guest               15
# 54      55    10    1      second        guest               15
# 55      56    10    1      second        guest               15
# 56      57    10    1       first        guest               15
# 57      58    10    1      second        guest               30
# 58      59    10    1      second        guest               40
# 59      60    11    1       first         host                0
# 60      61    11    1      second         host                0
# 61      62    11    1       first         host                0
# 62      63    11    1       first         host               15
# 63      64    11    1       first         host               30
# 64      65    11    1       first         host               40
# 65      66    11    1       first         host               40
# 66      67    12    1      second        guest                0
# 67      68    12    1       first        guest               15
# 68      69    12    1      second        guest               15
# 69      70    12    1       first        guest               30
# 70      71    12    1       first        guest               30
# 71      72    12    1       first        guest               30
# 72      73    13    2      second         host                0
# 73      74    13    2       first         host                0
# 74      75    13    2      second         host                0
# 75      76    13    2       first         host                0
# 76      77    13    2      second         host               15
# 77      78    14    2       first        guest                0
# 78      79    14    2       first        guest               15
# 79      80    14    2      second        guest               15
# 80      81    14    2      second        guest               15
# 81      82    14    2      second        guest               15
# 82      83    15    2      second         host                0
# 83      84    15    2       first         host               15
# 84      85    15    2      second         host               15
# 85      86    15    2      second         host               30
# 86      87    15    2      second         host               40
# 87      88    15    2       first         host               40
# 88      89    16    2      second        guest                0
# 89      90    16    2       first        guest                0
# 90      91    16    2       first        guest                0
# 91      92    16    2       first        guest               15
# 92      93    16    2       first        guest               15
# 93      94    17    2       first         host                0
# 94      95    17    2       first         host               15
# 95      96    17    2      second         host               30
# 96      97    17    2       first         host               30
# 97      98    17    2       first         host               40
# 98      99    17    2       first         host               40
# 99     100    17    2      second         host               40
# 100    101    18    2       first        guest                0
# 101    102    18    2       first        guest               15
# 102    103    18    2      second        guest               30
# 103    104    18    2       first        guest               40
# 104    105    19    2       first         host                0
# 105    106    19    2       first         host               15
# 106    107    19    2       first         host               15
# 107    108    19    2       first         host               30
# 108    109    19    2      second         host               30
# 109    110    19    2       first         host               30
# 110    111    19    2       first         host               40
# 111    112    20    2       first        guest                0
# 112    113    20    2       first        guest                0
# 113    114    20    2       first        guest                0
# 114    115    20    2       first        guest               15
# 115    116    20    2       first        guest               15
#
#      Guest Game Score Point Winner                   Detail  Break Point  \
# 0                   0        guest  Forehand Unforced Error        False
# 1                  15        guest             Double Fault        False
# 2                  30        guest  Forehand Unforced Error        False
# 3                  40        guest  Forehand Unforced Error         True
# 4                   0         host             Double Fault        False
# 5                   0         host             Double Fault        False
# 6                   0         host  Backhand Unforced Error        False
# 7                   0         host  Forehand Unforced Error         True
# 8                   0        guest          Backhand Winner        False
# 9                  15        guest  Forehand Unforced Error        False
# 10                 30         host  Backhand Unforced Error        False
# 11                 30        guest  Forehand Unforced Error        False
# 12                 40         host                      NaN         True
# 13                 40         host           Service Winner         True
# 14                 40         host  Backhand Unforced Error         True
# 15                  0        guest           Service Winner        False
# 16                 15        guest  Backhand Unforced Error        False
# 17                 30         host  Forehand Unforced Error        False
# 18                 30         host             Double Fault        False
# 19                 30        guest           Service Winner        False
# 20                 40         host             Double Fault        False
# 21                 40         host  Forehand Unforced Error         True
# 22                  0         host  Forehand Unforced Error        False
# 23                  0         host           Service Winner        False
# 24                  0        guest  Backhand Unforced Error        False
# 25                 15         host  Forehand Unforced Error        False
# 26                 15        guest             Double Fault        False
# 27                 30        guest  Forehand Unforced Error        False
# 28                 40        guest             Double Fault         True
# 29                  0         host  Forehand Unforced Error        False
# 30                  0        guest           Service Winner        False
# 31                 15        guest                      NaN        False
# 32                 30         host  Forehand Unforced Error        False
# 33                 30         host             Double Fault        False
# 34                 30        guest  Forehand Unforced Error         True
# 35                 40         host             Double Fault         True
# 36                  0         host           Service Winner        False
# 37                  0         host           Service Winner        False
# 38                  0        guest  Forehand Unforced Error        False
# 39                 15        guest  Forehand Unforced Error        False
# 40                 30        guest                      NaN        False
# 41                 40         host           Service Winner         True
# 42                 40        guest  Forehand Unforced Error         True
# 43                  0        guest          Forehand Winner        False
# 44                 15        guest           Service Winner        False
# 45                 30        guest          Forehand Winner        False
# 46                 40        guest                      Ace        False
# 47                  0        guest             Double Fault        False
# 48                 15         host                      NaN        False
# 49                 15        guest  Forehand Unforced Error        False
# 50                 30        guest  Forehand Unforced Error        False
# 51                 40        guest          Backhand Winner         True
# 52                  0         host          Forehand Winner        False
# 53                  0        guest           Service Winner        False
# 54                 15        guest  Backhand Unforced Error        False
# 55                 30        guest  Forehand Unforced Error        False
# 56                 40         host  Forehand Unforced Error        False
# 57                 40         host  Forehand Unforced Error        False
# 58                 40         host             Double Fault         True
# 59                  0        guest  Backhand Unforced Error        False
# 60                 15        guest             Double Fault        False
# 61                 30         host                      NaN        False
# 62                 30         host                      NaN        False
# 63                 30         host           Service Winner        False
# 64                 30        guest  Forehand Unforced Error        False
# 65                 40        guest          Forehand Winner         True
# 66                  0         host  Backhand Unforced Error        False
# 67                  0        guest                      NaN        False
# 68                 15         host  Backhand Unforced Error        False
# 69                 15        guest          Forehand Winner        False
# 70                 30        guest  Forehand Unforced Error        False
# 71                 40        guest  Forehand Unforced Error        False
# 72                  0        guest  Backhand Unforced Error        False
# 73                 15        guest  Forehand Unforced Error        False
# 74                 30        guest  Forehand Unforced Error        False
# 75                 40         host           Service Winner         True
# 76                 40        guest  Forehand Unforced Error         True
# 77                  0         host  Forehand Unforced Error        False
# 78                  0        guest                      Ace        False
# 79                 15        guest           Service Winner        False
# 80                 30        guest           Service Winner        False
# 81                 40        guest  Backhand Unforced Error        False
# 82                  0         host  Forehand Unforced Error        False
# 83                  0        guest                      NaN        False
# 84                 15         host  Backhand Unforced Error        False
# 85                 15         host           Service Winner        False
# 86                 15        guest          Forehand Winner        False
# 87                 30         host           Service Winner        False
# 88                  0        guest          Forehand Winner        False
# 89                 15        guest  Backhand Unforced Error        False
# 90                 30         host                      NaN        False
# 91                 30        guest  Forehand Unforced Error        False
# 92                 40        guest  Backhand Unforced Error        False
# 93                  0         host  Forehand Unforced Error        False
# 94                  0         host           Service Winner        False
# 95                  0        guest  Backhand Unforced Error        False
# 96                 15         host  Forehand Unforced Error        False
# 97                 15        guest  Forehand Unforced Error        False
# 98                 30        guest  Forehand Unforced Error        False
# 99                 40        guest          Backhand Winner         True
# 100                 0         host  Forehand Unforced Error        False
# 101                 0         host  Forehand Unforced Error        False
# 102                 0         host             Double Fault        False
# 103                 0         host          Backhand Winner         True
# 104                 0         host  Forehand Unforced Error        False
# 105                 0        guest  Forehand Unforced Error        False
# 106                15         host  Forehand Unforced Error        False
# 107                15        guest          Forehand Winner        False
# 108                30        guest                      NaN        False
# 109                40         host           Service Winner         True
# 110                40        guest  Backhand Unforced Error         True
# 111                 0        guest  Forehand Unforced Error        False
# 112                15        guest          Forehand Winner        False
# 113                30         host  Backhand Unforced Error        False
# 114                30        guest          Backhand Winner        False
# 115                40        guest                      Ace        False
#
#      Set Point  Favorited Start Time   Video Time   Duration
# 0        False      False   22:45:26    27.020000  14.800000
# 1        False      False   22:46:45   106.949997   1.700000
# 2        False      False   22:47:37   158.149994   3.300000
# 3        False      False   22:48:05   186.279999  12.980000
# 4        False      False   22:48:42   223.880005   1.980000
# 5        False      False   22:49:02   243.380005  14.770000
# 6        False      False   22:49:30   271.149994  13.930000
# 7        False      False   22:50:00   301.350006  12.730000
# 8        False      False   22:50:40   341.079987   2.080000
# 9        False      False   22:50:57   358.859985   3.080000
# 10       False      False   22:51:34   395.049988  17.100000
# 11       False      False   22:52:15   436.079987  19.480000
# 12       False      False   22:53:02   483.179993  12.880000
# 13       False      False   22:53:40   521.909973  16.950001
# 14       False      False   22:54:31   572.479980   5.930000
# 15       False      False   22:56:05   666.140015   3.130000
# 16       False      False   22:56:18   679.309998   4.900000
# 17       False      False   22:56:36   697.479980   5.980000
# 18       False      False   22:57:02   723.539978  10.920000
# 19       False      False   22:57:36   757.340027  11.630000
# 20       False      False   22:58:12   793.210022  14.050000
# 21       False      False   22:58:36   817.809998   3.450000
# 22       False      False   22:59:08   849.479980  16.280001
# 23       False      False   22:59:57   898.340027   1.520000
# 24       False      False   23:00:17   918.409973  13.470000
# 25       False      False   23:00:51   952.739990   7.370000
# 26       False      False   23:01:19   980.010010  14.570000
# 27       False      False   23:01:57  1018.409973   3.770000
# 28       False      False   23:02:26  1047.439941  12.370000
# 29       False      False   23:04:09  1150.040039   4.530000
# 30       False      False   23:04:31  1172.540039   2.320000
# 31       False      False   23:04:49  1190.369995   1.970000
# 32       False      False   23:05:09  1210.239990   5.920000
# 33       False      False   23:05:31  1232.540039   9.130000
# 34       False      False   23:06:08  1269.109985  12.030000
# 35       False      False   23:06:41  1302.969971   9.800000
# 36       False      False   23:07:34  1355.569946   1.880000
# 37       False      False   23:07:57  1378.000000  10.150000
# 38       False      False   23:08:25  1406.800049   2.650000
# 39       False      False   23:08:47  1428.349976   6.400000
# 40       False      False   23:09:19  1460.369995  14.980000
# 41       False      False   23:10:00  1501.439941   2.130000
# 42       False      False   23:10:23  1524.069946  16.580000
# 43       False      False   23:12:05  1626.939941   5.100000
# 44       False      False   23:12:29  1650.300049   1.550000
# 45       False      False   23:12:49  1670.069946   7.230000
# 46       False      False   23:13:21  1702.599976   0.430000
# 47       False      False   23:13:44  1725.369995   9.770000
# 48       False      False   23:14:14  1755.099976   4.730000
# 49       False      False   23:14:44  1785.300049   9.450000
# 50       False      False   23:15:30  1831.300049   8.000000
# 51       False      False   23:16:06  1867.500000  12.000000
# 52       False      False   23:17:43  1964.270020  14.170000
# 53       False      False   23:18:17  1998.900024  11.450000
# 54       False      False   23:18:48  2029.900024  13.650000
# 55       False      False   23:19:44  2085.399902  20.150000
# 56       False      False   23:20:21  2122.459961   3.080000
# 57       False      False   23:20:43  2144.929932  27.620001
# 58       False      False   23:21:36  2197.300049  15.850000
# 59       False      False   23:22:17  2238.350098   6.000000
# 60       False      False   23:22:42  2263.449951  36.049999
# 61       False      False   23:23:39  2320.330078   1.920000
# 62       False      False   23:23:57  2338.060059   2.580000
# 63       False      False   23:24:32  2373.629883   5.170000
# 64       False      False   23:24:52  2393.939941   7.800000
# 65       False      False   23:25:23  2424.729980   4.920000
# 66       False      False   23:26:53  2514.060059  21.780001
# 67       False      False   23:27:43  2564.189941   1.950000
# 68       False      False   23:28:00  2581.760010  17.280001
# 69       False      False   23:28:41  2622.389893   5.630000
# 70       False      False   23:29:10  2651.360107  16.879999
# 71       False      False   23:29:56  2697.590088   5.450000
# 72       False      False   23:32:35  2856.659912  13.170000
# 73       False      False   23:33:17  2898.419922   5.030000
# 74       False      False   23:33:43  2924.959961  11.870000
# 75       False      False   23:34:19  2960.120117   4.370000
# 76       False      False   23:34:38  2979.959961  11.630000
# 77       False      False   23:35:57  3058.419922   8.220000
# 78       False      False   23:36:23  3084.949951   0.370000
# 79       False      False   23:36:43  3104.949951  10.930000
# 80       False      False   23:37:17  3138.149902  13.180000
# 81       False      False   23:37:53  3174.719971  15.330000
# 82       False      False   23:38:32  3213.649902  30.080000
# 83       False      False   23:39:35  3276.120117   3.500000
# 84       False      False   23:40:07  3308.820068  21.719999
# 85       False      False   23:41:00  3361.550049  14.000000
# 86       False      False   23:41:40  3401.250000  12.230000
# 87       False      False   23:42:18  3439.750000   2.700000
# 88       False      False   23:43:42  3523.620117  18.000000
# 89       False      False   23:44:20  3561.750000   3.980000
# 90       False      False   23:44:41  3582.679932   3.200000
# 91       False      False   23:45:02  3603.750000   4.930000
# 92       False      False   23:45:19  3620.179932   4.550000
# 93       False      False   23:45:50  3651.250000   4.080000
# 94       False      False   23:46:17  3678.179932   1.450000
# 95       False      False   23:46:37  3698.550049  13.180000
# 96       False      False   23:47:16  3737.750000   4.480000
# 97       False      False   23:47:47  3768.379883   5.950000
# 98       False      False   23:48:17  3798.929932   2.400000
# 99       False      False   23:48:42  3823.909912  11.630000
# 100      False      False   23:50:32  3933.379883   2.550000
# 101      False      False   23:50:59  3960.810059   6.600000
# 102      False      False   23:51:28  3989.679932   9.250000
# 103      False      False   23:52:06  4027.709961   3.230000
# 104      False      False   23:52:28  4049.580078   4.230000
# 105      False      False   23:52:53  4074.209961  13.620000
# 106      False      False   23:53:41  4122.439941   5.770000
# 107      False      False   23:54:15  4156.740234   1.530000
# 108      False      False   23:54:42  4183.080078  10.200000
# 109      False      False   23:55:14  4215.680176   1.650000
# 110      False      False   23:55:38  4239.740234  24.080000
# 111      False      False   23:57:40  4361.680176   4.050000
# 112      False      False   23:58:10  4391.129883   4.780000
# 113      False      False   23:58:34  4415.779785   5.200000
# 114      False      False   23:58:54  4435.919922   6.120000
# 115      False      False   23:59:18  4459.669922   1.100000

# %% [markdown]
# ### Basic Functions for Quick Analysis
# `df.head()`
#
# Gives you the **FIRST** 5 observations/rows
# - If you put a number within the parentheses you will get that number of rows

# %% [markdown]
# `df.tail()`
# Gives you the **LAST** 5 observations/rows

# %% [markdown]
# `df.sample()`
#
# Gives you a **RANDOM** observation sample
#
# Arguments: frac, random_state

# %% [markdown]
# `df.columns`
#
# Gives you all the column names of your dataset

# %% [markdown]
# `df.index`
#
# Gives you the index values in the dataframe

# %% [markdown]
# Use the `list()` function to see all the numbers

# %% [markdown]
# `df.info()`

# %% [markdown]
# `df.describe()`

# %% [markdown]
# `df.shape`

# %% [markdown]
# `len()`

# %%
sample_data = range(0, 10)
len(sample_data)
# list(sample_data)

# %%
sample_data = data['Name']
len(sample_data)
# data['Name']

# %% [markdown]
# ### How to Subset your Dataframe
# One Column: `df[]`
#
# Multiple Columns: `df[[ ]]`

# %% [markdown]
# ### How to Filter your dataframe
#
# `df.loc[]` and `df.iloc[]`
#
# `df.loc[df['column'] == 'condition']`

# %% [markdown]
# ### Conditional Subsetting & Querying
# `&`
#
# `|`

# %% [markdown]
# `.query()`
# 1. Filter when the `serverName` is equal to `Kaylan Bigun`
# 2. Also Filter all of his Aces
#
# Can use many conditions (==, != , >, <, >=, <=)

# %% [markdown]
# ### Summarizing the Data (Numerical)
# `.mean()`
#
# `.max()`
#
# `.min()`
#
# `.std()`
#
# `.var()`
#
# `.quantile`

# %% [markdown]
# ### Can also do for multiple Columns
# `df[['column', 'column', ...]].mean()`

# %% [markdown]
# ### Use the Aggregate Function
#
# `.agg()`

# %% [markdown]
# `df[['column', 'column', ...]].agg(['mean', 'sum', 'max'])`

# %% [markdown]
# `.sum()`

# %% [markdown]
# `.count()`

# %% [markdown]
# ### Summarizing the Data (Categorial)
#
# `.unique()`

# %% [markdown]
# `.nunique()`
#
# Same as len(df.unique())

# %% [markdown]
# `.value_counts()`
#
# Arguments: normalize (True, False)
#
#
# Find the value counts of `firstServeZone`
#
# Find the value counts of `firstServeZone` and `firstServeIn`

# %% [markdown]
# ### GroupBy Methods
# `df.groupby()`

# %% [markdown]
# ### Handling Missing Values
# `.isna()`
#
# `.dropna()`
#
# `.fillna()`

# %% [markdown]
# ### How to save/write your CSV
# `.to_csv()`

# %% [markdown]
# ### Problems to Practice Yourself!!
#
# #### Problem 1: From the `Shot_Visuals_KaylanBigun_NathanTrouve.csv` dataset, create two tables
# 1. Table of the **counts** of the zones Kaylan had served into for his firstServe (including made adn missed)
# 1. Table of the **percentage** of the zones Kaylan had served into for his firstServe ((including made adn missed))

# %%
# Subsetting
# Conditional/Querying 
# value_counts()

# %% [markdown]
# #### Problem 2: From the `(playsight)kaylan_usc.xlsx` dataset (Download from slack!)
# Find the minimum, maximum, and average speed of Kaylan's stroke type

# %%
# .agg() (.max(), .mean(), .sum())
# value_counts()
