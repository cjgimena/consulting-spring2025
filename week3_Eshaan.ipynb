# %% [markdown]
# ## Week 3: Jupyter Notebook - Pandas GroupBy, Apply, and Create Your Own Functions
# Make sure to select your Kernel before starting!

# %% [markdown]
# ### Import Pandas Library/Package
# `import pandas as pd`

# %%
import pandas as pd

# %% [markdown]
# ### Optional: Displaying your Dataframe
# Don't use for big datasets

# %%
pd.set_option("display.max_columns", None)  # Show all columns
pd.set_option("display.max_rows", None)     # Show all rows

# %% [markdown]
# ### GroupBy Functions
# `df.groupby()`

# %% [markdown]
# Create own dataset

# %%
data = {
    'Name': ['Zophie', 'Alice', 'Bob', 'Charlie', 'Max', 'Milo', 'Luna', 'Bella'],
    'Age': [7, 5, 3, 2, 5, 3, 2, 5],
    'Color': ['Gray', 'Black', 'Brown', 'White', 'Black', 'Brown', 'White', 'Black'],
    'Owner': ['Charles', 'Charles', 'Cj', 'Cj', 'Cj', 'Charles', 'Cj', 'Charles'],
    'Type': ['Cat', 'Cat', 'Dog', 'Dog', 'Dog', 'Cat', 'Dog', 'Cat']
}

# Create DataFrame
df = pd.DataFrame(data)
df

# %% [markdown]
# Count how many pets of each color each owner has
#
# `.size()`

# %%
# Group By Owner and Color
df.groupby(['Owner', 'Color']).size()

# %% [markdown]
# ### Read In Datasets
# `pd.read_csv()`
#
# Read in the file from the data folder called `Shot_Visuals_KaylanBigun_NathanTrouve.csv`

# %%
# Read data and create df variable
shots = pd.read_csv('data/Shot_Visuals_KaylanBigun_NathanTrouve.csv')
# Print the head of the object
shots.head()

# %% [markdown]
# ##### Create Sample dataframe
# - save as `sample_df`
# - First 3 points

# %%
# sample_df and first 3 points
sample_df = shots.head(11)
sample_df

# %% [markdown]
# Group By `pointNumber` and subset the columns `pointStartTime`
#
# Use the `.first()` function to grab the first value

# %%
sample_df.groupby('pointNumber')['pointStartTime'].first()

# %% [markdown]
# Use the `.last()` function to grab the last value

# %%
sample_df.groupby('pointNumber')['pointStartTime'].last()

# %% [markdown]
# ### Create your own functions
#
# `def function()`

# %%
# set a variable x = 2
x = 2   
# print variable x
x

# %%
# Create a function that takes a variable x and returns x + 1
def function(x):
    answer = x + 1
    return answer

# %%
function(4)

# %% [markdown]
# ##### Personalize your function name and add multiple arguments

# %%
# Create a function that takes a variable x and returns x + 2
def add_two(x):
    answer = x + 2
    return answer

# %%
# print function and arguments
add_two(6)

# %% [markdown]
# ### Apply Functions
# `.apply()`

# %%
# Use the pets dataset for this example
df

# %%
# Add 1 to the Age column of the pets dataset
df['Age'] = df['Age'].apply(lambda x: x + 1)
df['Age']

# %%
# same as creating your own function
def function(x):
    answer = x * 10
    return answer

df['Age'] = df['Age'].apply(function)
df['Age']

# %%
# Also use the summarizing functions (mean, max, mean)
df['Age'].apply('mean')

# %%
df['Age'].apply('max')

# %%
# But the same as this

df['Age'] + 1

# %% [markdown]
# But if you notice this code below gives us the same as our `plus_one()` function

# %% [markdown]
# Use case is in the conditional statements!!

# %%
# create a function that classifies 5 years and younger as 'young' and everything above 'old'

def classify_age(age):
    if age <= 5:
        return 'young'
    else:
        return 'old'
    
df['life_stage'] = df['Age'].apply(classify_age)
df

# %% [markdown]
# Create a new Column called duration in `new_df`
# - using the apply function **row-rise**

# %%
# new_df
new_df = sample_df.groupby('pointNumber')[['pointStartTime']].first()
new_df

# %%
new_df['pointEndTime'] = sample_df.groupby('pointNumber')[['pointEndTime']].last()
new_df

# %%
def duration(end, start):
    duration = end - start
    return duration

new_df['duration'] = new_df.apply(lambda x: duration(x['pointEndTime'], x['pointStartTime']), axis = 1)
new_df

# %% [markdown]
# But as you notice this function could be simplified to...

# %%
new_df['duration2'] = new_df['pointEndTime'] - new_df['pointStartTime']
new_df

# %% [markdown]
# Use case is in the conditional statements!!

# %% [markdown]
# ### Problems to Practice Yourself!!
#
# #### Problem 1: From the `(playsight)kaylan_usc.xlsx` dataset, classify the speed of the ball
# - More than 110: **Fast**
# - Less than 110 and greater than 70: **Regular**
# - Less than 70: **Slow**

# %%
import pandas as pd

shots_excel = pd.read_excel('data/(playsight)kaylan_usc.xlsx', sheet_name='Shots')
shots_excel.head()

def classifySpeed(speed):
    if speed >= 110:
        return 'fast'
    elif speed >= 70:
        return 'regular'
    else:
        return 'slow'
    
shots_excel['ClassifiedSpeed'] = shots_excel['Speed (MPH)'].apply(classifySpeed)
shots_excel

# %% [markdown]
# #### Problem 2: From the `Shot_Visuals_KaylanBigun_NathanTrouve.csv` dataset, create a new column called "shot_depth"
# - Use the image below to classify shots as deep, short, and long
# - Create a function that takes the arguments `shotLocationX` and `shotLocationY` to create the outputs **short**, **deep**, and **long**

# %%
from IPython.display import Image

Image(filename='images/court_dimensions.jpg', width=250)

# IN RELATION TO THIS DATASET'S COORDINATES

# Origin is at the center of the court
# 455 is the top of the court, -455 is the bottom of the court
# -210 is the left side of the court, 210 is the right side of the court

# %%
# read in the dataset
shots = pd.read_csv('data/Shot_Visuals_KaylanBigun_NathanTrouve.csv')
shots.head()

# %%
# create function
def classifyShotDepth(shotLocationX, shotLocationY):
    if pd.isna(shotLocationX) or pd.isna(shotLocationY):
        return None
    elif (-157.5 <= shotLocationX <= 157.5) and (-245 <= shotLocationY <= 245):
        return 'short'
    elif (-157.5 <= shotLocationX <= 157.5) and (shotLocationY <= -245 or shotLocationY >= 245):
        return 'deep'
    else:
        return 'long'

# %%
# apply function
shots['ShotDepth'] = shots.apply(lambda x: classifyShotDepth(x['shotLocationX'], x['shotLocationY']), axis = 1)
shots.head()
# Out:
#     pointScore gameScore setScore  isPointStart  pointStartTime  isPointEnd  \
# 0          0-0       0-0      0-0           1.0         25020.0         NaN
# 1          0-0       0-0      0-0           NaN         36320.0         NaN
# 2          0-0       0-0      0-0           NaN         37349.0         NaN
# 3          0-0       0-0      0-0           NaN         38549.0         1.0
# 4         15-0       0-0      0-0           1.0         57814.0         1.0
# 5         30-0       0-0      0-0           1.0         61671.0         NaN
# 6         30-0       0-0      0-0           NaN         81681.0         NaN
# 7         30-0       0-0      0-0           NaN         82877.0         NaN
# 8         30-0       0-0      0-0           NaN         84155.0         NaN
# 9         30-0       0-0      0-0           NaN         85964.0         NaN
# 10        30-0       0-0      0-0           NaN         87340.0         1.0
# 11        40-0       0-0      0-0           1.0        104949.0         NaN
# 12        40-0       0-0      0-0           NaN        105620.0         1.0
# 13         0-0       1-0      0-0           1.0        156149.0         NaN
# 14         0-0       1-0      0-0           NaN        156979.0         NaN
# 15         0-0       1-0      0-0           NaN        158580.0         1.0
# 16        0-15       1-0      0-0           1.0        184279.0         NaN
# 17        0-15       1-0      0-0           NaN        194169.0         NaN
# 18        0-15       1-0      0-0           NaN        195250.0         NaN
# 19        0-15       1-0      0-0           NaN        196669.0         1.0
# 20       15-15       1-0      0-0           1.0        221880.0         NaN
# 21       15-15       1-0      0-0           NaN        222669.0         1.0
# 22       30-15       1-0      0-0           1.0        241380.0         1.0
# 23       30-30       1-0      0-0           1.0        269149.0         NaN
# 24       30-30       1-0      0-0           NaN        269920.0         NaN
# 25       30-30       1-0      0-0           NaN        271769.0         NaN
# 26       30-30       1-0      0-0           NaN        273079.0         NaN
# 27       30-30       1-0      0-0           NaN        274179.0         NaN
# 28       30-30       1-0      0-0           NaN        275480.0         NaN
# 29       30-30       1-0      0-0           NaN        276880.0         NaN
# 30       30-30       1-0      0-0           NaN        278220.0         NaN
# 31       30-30       1-0      0-0           NaN        279380.0         NaN
# 32       30-30       1-0      0-0           NaN        280869.0         NaN
# 33       30-30       1-0      0-0           NaN        282019.0         1.0
# 34       30-40       1-0      0-0           1.0        299350.0         NaN
# 35       30-40       1-0      0-0           NaN        309820.0         NaN
# 36       30-40       1-0      0-0           NaN        311119.0         1.0
# 37         0-0       2-0      0-0           1.0        339079.0         NaN
# 38         0-0       2-0      0-0           NaN        339609.0         1.0
# 39        0-15       2-0      0-0           1.0        356859.0         NaN
# 40        0-15       2-0      0-0           NaN        357760.0         NaN
# 41        0-15       2-0      0-0           NaN        359279.0         1.0
# 42        0-30       2-0      0-0           1.0        393049.0         NaN
# 43        0-30       2-0      0-0           NaN        404079.0         NaN
# 44        0-30       2-0      0-0           NaN        405380.0         NaN
# 45        0-30       2-0      0-0           NaN        406679.0         NaN
# 46        0-30       2-0      0-0           NaN        407950.0         NaN
# 47        0-30       2-0      0-0           NaN        409359.0         1.0
# 48       15-30       2-0      0-0           1.0        434079.0         NaN
# 49       15-30       2-0      0-0           NaN        445880.0         NaN
# 50       15-30       2-0      0-0           NaN        446959.0         NaN
# 51       15-30       2-0      0-0           NaN        448079.0         NaN
# 52       15-30       2-0      0-0           NaN        451510.0         NaN
# 53       15-30       2-0      0-0           NaN        452950.0         1.0
# 54       15-40       2-0      0-0           1.0        481179.0         NaN
# 55       15-40       2-0      0-0           NaN        491450.0         1.0
# 56       30-40       2-0      0-0           1.0        519909.0         NaN
# 57       30-40       2-0      0-0           NaN        536359.0         1.0
# 58       40-40       2-0      0-0           1.0        570479.0         NaN
# 59       40-40       2-0      0-0           NaN        571309.0         NaN
# 60       40-40       2-0      0-0           NaN        572809.0         NaN
# 61       40-40       2-0      0-0           NaN        574280.0         NaN
# 213      30-15       4-5      0-0           NaN       2096100.0         NaN
# 214      30-15       4-5      0-0           NaN       2097659.0         NaN
# 215      30-15       4-5      0-0           NaN       2098830.0         NaN
# 216      30-15       4-5      0-0           NaN       2100330.0         NaN
# 217      30-15       4-5      0-0           NaN       2101449.0         1.0
# 218      40-15       4-5      0-0           1.0       2120459.0         NaN
# 219      40-15       4-5      0-0           NaN       2121260.0         NaN
# 220      40-15       4-5      0-0           NaN       2122699.0         1.0
# 221      40-30       4-5      0-0           1.0       2142929.0         NaN
# 222      40-30       4-5      0-0           NaN       2162530.0         NaN
# 223      40-30       4-5      0-0           NaN       2164550.0         NaN
# 224      40-30       4-5      0-0           NaN       2165959.0         NaN
# 225      40-30       4-5      0-0           NaN       2167229.0         NaN
# 226      40-30       4-5      0-0           NaN       2168399.0         NaN
# 227      40-30       4-5      0-0           NaN       2169659.0         1.0
# 228      40-40       4-5      0-0           1.0       2195300.0         NaN
# 229      40-40       4-5      0-0           NaN       2209250.0         1.0
# 230        0-0       5-5      0-0           1.0       2236350.0         NaN
# 231        0-0       5-5      0-0           NaN       2237060.0         NaN
# 232        0-0       5-5      0-0           NaN       2238449.0         NaN
# 233        0-0       5-5      0-0           NaN       2239699.0         NaN
# 234        0-0       5-5      0-0           NaN       2241250.0         1.0
# 235       0-15       5-5      0-0           1.0       2285176.0         1.0
# 236       0-30       5-5      0-0           1.0       2318330.0         NaN
# 237       0-30       5-5      0-0           NaN       2318899.0         1.0
# 238      15-30       5-5      0-0           1.0       2336060.0         NaN
# 239      15-30       5-5      0-0           NaN       2336949.0         1.0
# 240      30-30       5-5      0-0           1.0       2371629.0         NaN
# 241      30-30       5-5      0-0           NaN       2372260.0         NaN
# 242      30-30       5-5      0-0           NaN       2373560.0         NaN
# 243      30-30       5-5      0-0           NaN       2375050.0         1.0
# 244      40-30       5-5      0-0           1.0       2391939.0         NaN
# 245      40-30       5-5      0-0           NaN       2392939.0         NaN
# 246      40-30       5-5      0-0           NaN       2394459.0         NaN
# 247      40-30       5-5      0-0           NaN       2395929.0         NaN
# 248      40-30       5-5      0-0           NaN       2397389.0         NaN
# 249      40-30       5-5      0-0           NaN       2398659.0         NaN
# 250      40-30       5-5      0-0           NaN       2399540.0         1.0
# 251      40-40       5-5      0-0           1.0       2421938.0         NaN
# 252      40-40       5-5      0-0           NaN       2425079.0         NaN
# 253      40-40       5-5      0-0           NaN       2426680.0         1.0
# 254        0-0       5-6      0-0           1.0       2512060.0         NaN
# 255        0-0       5-6      0-0           NaN       2521030.0         NaN
# 256        0-0       5-6      0-0           NaN       2522139.0         NaN
# 257        0-0       5-6      0-0           NaN       2523389.0         NaN
# 258        0-0       5-6      0-0           NaN       2524929.0         NaN
# 259        0-0       5-6      0-0           NaN       2526139.0         NaN
# 260        0-0       5-6      0-0           NaN       2527429.0         NaN
# 261        0-0       5-6      0-0           NaN       2528629.0         NaN
# 262        0-0       5-6      0-0           NaN       2530030.0         NaN
# 263        0-0       5-6      0-0           NaN       2531629.0         NaN
# 264        0-0       5-6      0-0           NaN       2532929.0         1.0
# 265       0-15       5-6      0-0           1.0       2562189.0         NaN
# 266       0-15       5-6      0-0           NaN       2563129.0         1.0
# 267      15-15       5-6      0-0           1.0       2579760.0         NaN
# 268      15-15       5-6      0-0           NaN       2592159.0         NaN
# 269      15-15       5-6      0-0           NaN       2593439.0         NaN
# 270      15-15       5-6      0-0           NaN       2594959.0         NaN
# 271      15-15       5-6      0-0           NaN       2596129.0         1.0
# 272      15-30       5-6      0-0           1.0       2620389.0         NaN
# 273      15-30       5-6      0-0           NaN       2621239.0         NaN
# 274      15-30       5-6      0-0           NaN       2622659.0         NaN
# 275      15-30       5-6      0-0           NaN       2623860.0         NaN
# 276      15-30       5-6      0-0           NaN       2625459.0         1.0
# 277      30-30       5-6      0-0           1.0       2648647.0         NaN
# 278      30-30       5-6      0-0           NaN       2651418.0         NaN
# 279      30-30       5-6      0-0           NaN       2653193.0         NaN
# 280      30-30       5-6      0-0           NaN       2654172.0         NaN
# 281      30-30       5-6      0-0           NaN       2655360.0         NaN
# 282      30-30       5-6      0-0           NaN       2656591.0         NaN
# 283      30-30       5-6      0-0           NaN       2658299.0         NaN
# 284      30-30       5-6      0-0           NaN       2660044.0         NaN
# 285      30-30       5-6      0-0           NaN       2660685.0         NaN
# 286      30-30       5-6      0-0           NaN       2662445.0         NaN
# 287      30-30       5-6      0-0           NaN       2663917.0         NaN
# 288      30-30       5-6      0-0           NaN       2664918.0         NaN
# 289      30-30       5-6      0-0           NaN       2666049.0         NaN
# 290      30-30       5-6      0-0           NaN       2667196.0         1.0
# 291      40-30       5-6      0-0           1.0       2695590.0         NaN
# 292      40-30       5-6      0-0           NaN       2696189.0         NaN
# 293      40-30       5-6      0-0           NaN       2697729.0         NaN
# 294      40-30       5-6      0-0           NaN       2698760.0         1.0
# 295        0-0       0-0      0-1           1.0       2854659.0         NaN
# 296        0-0       0-0      0-1           NaN       2863939.0         NaN
# 297        0-0       0-0      0-1           NaN       2865290.0         NaN
# 298        0-0       0-0      0-1           NaN       2867040.0         1.0
# 299       0-15       0-0      0-1           1.0       2896419.0         NaN
# 300       0-15       0-0      0-1           NaN       2897219.0         NaN
# 301       0-15       0-0      0-1           NaN       2899020.0         NaN
# 302       0-15       0-0      0-1           NaN       2900120.0         1.0
# 303      15-15       0-0      0-1           1.0       2922959.0         NaN
# 304      15-15       0-0      0-1           NaN       2932040.0         NaN
# 305      15-15       0-0      0-1           NaN       2933520.0         1.0
# 306      15-30       0-0      0-1           1.0       2958120.0         NaN
# 307      15-30       0-0      0-1           NaN       2958959.0         NaN
# 308      15-30       0-0      0-1           NaN       2960020.0         1.0
# 309      15-40       0-0      0-1           1.0       2977959.0         NaN
# 310      15-40       0-0      0-1           NaN       2987340.0         NaN
# 311      15-40       0-0      0-1           NaN       2988620.0         1.0
# 312        0-0       0-1      0-1           1.0       3056419.0         NaN
# 313        0-0       0-1      0-1           NaN       3057340.0         NaN
# 314        0-0       0-1      0-1           NaN       3058719.0         NaN
# 315        0-0       0-1      0-1           NaN       3060040.0         NaN
# 316        0-0       0-1      0-1           NaN       3061449.0         NaN
# 317        0-0       0-1      0-1           NaN       3062520.0         NaN
# 318        0-0       0-1      0-1           NaN       3063840.0         1.0
# 319       0-15       0-1      0-1           1.0       3082949.0         1.0
# 320      15-15       0-1      0-1           1.0       3102949.0         NaN
# 321      15-15       0-1      0-1           NaN       3112840.0         1.0
# 322      30-15       0-1      0-1           1.0       3136149.0         NaN
# 323      30-15       0-1      0-1           NaN       3148350.0         1.0
# 324      40-15       0-1      0-1           1.0       3172719.0         NaN
# 325      40-15       0-1      0-1           NaN       3185989.0         NaN
# 326      40-15       0-1      0-1           NaN       3187290.0         1.0
# 327        0-0       0-2      0-1           1.0       3211649.0         NaN
# 328        0-0       0-2      0-1           NaN       3229889.0         NaN
# 329        0-0       0-2      0-1           NaN       3230949.0         NaN
# 330        0-0       0-2      0-1           NaN       3232320.0         NaN
# 331        0-0       0-2      0-1           NaN       3233649.0         NaN
# 332        0-0       0-2      0-1           NaN       3234689.0         NaN
# 333        0-0       0-2      0-1           NaN       3236090.0         NaN
# 334        0-0       0-2      0-1           NaN       3237489.0         NaN
# 335        0-0       0-2      0-1           NaN       3239840.0         NaN
# 336        0-0       0-2      0-1           NaN       3240949.0         1.0
# 337       15-0       0-2      0-1           1.0       3274120.0         NaN
# 338       15-0       0-2      0-1           NaN       3274939.0         NaN
# 339       15-0       0-2      0-1           NaN       3277050.0         1.0
# 340      15-15       0-2      0-1           1.0       3306820.0         NaN
# 341      15-15       0-2      0-1           NaN       3321020.0         NaN
# 342      15-15       0-2      0-1           NaN       3322340.0         NaN
# 343      15-15       0-2      0-1           NaN       3323590.0         NaN
# 344      15-15       0-2      0-1           NaN       3325739.0         NaN
# 345      15-15       0-2      0-1           NaN       3327139.0         1.0
# 346      30-15       0-2      0-1           1.0       3359550.0         NaN
# 347      30-15       0-2      0-1           NaN       3371850.0         1.0
# 348      40-15       0-2      0-1           1.0       3399250.0         NaN
# 349      40-15       0-2      0-1           NaN       3408250.0         NaN
# 350      40-15       0-2      0-1           NaN       3409780.0         NaN
# 351      40-15       0-2      0-1           NaN       3410780.0         1.0
# 352      40-30       0-2      0-1           1.0       3437750.0         NaN
# 353      40-30       0-2      0-1           NaN       3438830.0         1.0
# 354        0-0       1-2      0-1           1.0       3521620.0         NaN
# 355        0-0       1-2      0-1           NaN       3535050.0         NaN
# 356        0-0       1-2      0-1           NaN       3536330.0         NaN
# 357        0-0       1-2      0-1           NaN       3537520.0         NaN
# 358        0-0       1-2      0-1           NaN       3538780.0         1.0
# 359       15-0       1-2      0-1           1.0       3559750.0         NaN
# 360       15-0       1-2      0-1           NaN       3560629.0         NaN
# 361       15-0       1-2      0-1           NaN       3561879.0         NaN
# 362       15-0       1-2      0-1           NaN       3563149.0         1.0
# 363       30-0       1-2      0-1           1.0       3580679.0         NaN
# 364       30-0       1-2      0-1           NaN       3581280.0         NaN
# 365       30-0       1-2      0-1           NaN       3582719.0         1.0
# 366      30-15       1-2      0-1           1.0       3601750.0         NaN
# 367      30-15       1-2      0-1           NaN       3602629.0         NaN
# 368      30-15       1-2      0-1           NaN       3604149.0         NaN
# 369      30-15       1-2      0-1           NaN       3605330.0         1.0
# 370      40-15       1-2      0-1           1.0       3618179.0         NaN
# 371      40-15       1-2      0-1           NaN       3619479.0         NaN
# 372      40-15       1-2      0-1           NaN       3620679.0         NaN
# 373      40-15       1-2      0-1           NaN       3621979.0         1.0
# 374        0-0       1-3      0-1           1.0       3649250.0         NaN
# 375        0-0       1-3      0-1           NaN       3650050.0         NaN
# 376        0-0       1-3      0-1           NaN       3651320.0         NaN
# 377        0-0       1-3      0-1           NaN       3652580.0         1.0
# 378       15-0       1-3      0-1           1.0       3676179.0         NaN
# 379       15-0       1-3      0-1           NaN       3677219.0         1.0
# 380       30-0       1-3      0-1           1.0       3696550.0         NaN
# 381       30-0       1-3      0-1           NaN       3707649.0         NaN
# 382       30-0       1-3      0-1           NaN       3708780.0         1.0
# 383      30-15       1-3      0-1           1.0       3735750.0         NaN
# 384      30-15       1-3      0-1           NaN       3736750.0         NaN
# 385      30-15       1-3      0-1           NaN       3738419.0         NaN
# 386      30-15       1-3      0-1           NaN       3739729.0         1.0
# 387      40-15       1-3      0-1           1.0       3766379.0         NaN
# 388      40-15       1-3      0-1           NaN       3767229.0         NaN
# 389      40-15       1-3      0-1           NaN       3769050.0         NaN
# 390      40-15       1-3      0-1           NaN       3770350.0         NaN
# 391      40-15       1-3      0-1           NaN       3771409.0         1.0
# 392      40-30       1-3      0-1           1.0       3796790.0         NaN
# 393      40-30       1-3      0-1           NaN       3799083.0         NaN
# 394      40-30       1-3      0-1           NaN       3800593.0         1.0
# 395      40-40       1-3      0-1           1.0       3821909.0         NaN
# 396      40-40       1-3      0-1           NaN       3832949.0         1.0
# 397        0-0       1-4      0-1           1.0       3931379.0         NaN
# 398        0-0       1-4      0-1           NaN       3932229.0         NaN
# 399        0-0       1-4      0-1           NaN       3933149.0         1.0
# 400       0-15       1-4      0-1           1.0       3958810.0         NaN
# 401       0-15       1-4      0-1           NaN       3959830.0         NaN
# 402       0-15       1-4      0-1           NaN       3961310.0         NaN
# 403       0-15       1-4      0-1           NaN       3963080.0         NaN
# 404       0-15       1-4      0-1           NaN       3964350.0         1.0
# 405       0-30       1-4      0-1           1.0       3987679.0         1.0
# 406       0-40       1-4      0-1           1.0       4025709.0         NaN
# 407       0-40       1-4      0-1           NaN       4026530.0         NaN
# 408       0-40       1-4      0-1           NaN       4027679.0         1.0
# 409        0-0       2-4      0-1           1.0       4047580.0         NaN
# 410        0-0       2-4      0-1           NaN       4048479.0         NaN
# 411        0-0       2-4      0-1           NaN       4049780.0         NaN
# 412        0-0       2-4      0-1           NaN       4050909.0         1.0
# 413       15-0       2-4      0-1           1.0       4072209.0         NaN
# 464       30-0       2-5      0-1           NaN       4415839.0         NaN
# 465       30-0       2-5      0-1           NaN       4417109.0         NaN
# 466       30-0       2-5      0-1           NaN       4418080.0         1.0
# 467      30-15       2-5      0-1           1.0       4433919.0         NaN
# 468      30-15       2-5      0-1           NaN       4434580.0         NaN
# 469      30-15       2-5      0-1           NaN       4436419.0         NaN
# 470      30-15       2-5      0-1           NaN       4439640.0         1.0
# 471      40-15       2-5      0-1           1.0       4457669.0         1.0
#
#      pointEndTime  pointNumber  isBreakPoint  shotInRally   side  \
# 0             NaN            1           NaN            1  Deuce
# 1             NaN            1           NaN            2  Deuce
# 2             NaN            1           NaN            3  Deuce
# 3         38549.0            1           NaN            4  Deuce
# 4         61681.0            2           NaN            1     Ad
# 5             NaN            3           NaN            1  Deuce
# 6             NaN            3           NaN            2  Deuce
# 7             NaN            3           NaN            3  Deuce
# 8             NaN            3           NaN            4     Ad
# 9             NaN            3           NaN            5     Ad
# 10        90130.0            3           NaN            6     Ad
# 11            NaN            4           NaN            1     Ad
# 12       105620.0            4           NaN            2     Ad
# 13            NaN            5           NaN            1  Deuce
# 14            NaN            5           NaN            2  Deuce
# 15       158580.0            5           NaN            3     Ad
# 16            NaN            6           1.0            1     Ad
# 17            NaN            6           1.0            2     Ad
# 18            NaN            6           1.0            3     Ad
# 19       196669.0            6           1.0            4  Deuce
# 20            NaN            7           NaN            1  Deuce
# 21       222669.0            7           NaN            2  Deuce
# 22            NaN            8           NaN            1     Ad
# 23            NaN            9           NaN            1  Deuce
# 24            NaN            9           NaN            2  Deuce
# 25            NaN            9           NaN            3     Ad
# 26            NaN            9           NaN            4     Ad
# 27            NaN            9           NaN            5     Ad
# 28            NaN            9           NaN            6     Ad
# 29            NaN            9           NaN            7     Ad
# 30            NaN            9           NaN            8  Deuce
# 31            NaN            9           NaN            9  Deuce
# 32            NaN            9           NaN           10     Ad
# 33       282019.0            9           NaN           11     Ad
# 34            NaN           10           1.0            1     Ad
# 35            NaN           10           1.0            2     Ad
# 36       311119.0           10           1.0            3     Ad
# 37            NaN           11           NaN            1  Deuce
# 38       339609.0           11           NaN            2  Deuce
# 39            NaN           12           NaN            1     Ad
# 40            NaN           12           NaN            2     Ad
# 41       359279.0           12           NaN            3     Ad
# 42            NaN           13           NaN            1  Deuce
# 43            NaN           13           NaN            2  Deuce
# 44            NaN           13           NaN            3     Ad
# 45            NaN           13           NaN            4     Ad
# 46            NaN           13           NaN            5     Ad
# 47       409359.0           13           NaN            6     Ad
# 48            NaN           14           NaN            1     Ad
# 49            NaN           14           NaN            2     Ad
# 50            NaN           14           NaN            3  Deuce
# 51            NaN           14           NaN            4  Deuce
# 52            NaN           14           NaN            5     Ad
# 53       452950.0           14           NaN            6     Ad
# 54            NaN           15           1.0            1  Deuce
# 55       491450.0           15           1.0            2  Deuce
# 56            NaN           16           1.0            1     Ad
# 57       536359.0           16           1.0            2     Ad
# 58            NaN           17           1.0            1  Deuce
# 131     1310040.0           38           1.0            1  Deuce
# 132           NaN           39           NaN            1  Deuce
# 133     1354569.0           39           NaN            2  Deuce
# 134           NaN           40           NaN            1     Ad
# 135     1385400.0           40           NaN            2     Ad
# 136           NaN           41           NaN            1  Deuce
# 137           NaN           41           NaN            2  Deuce
# 138     1406770.0           41           NaN            3  Deuce
# 139           NaN           42           NaN            1     Ad
# 140           NaN           42           NaN            2     Ad
# 141           NaN           42           NaN            3  Deuce
# 142           NaN           42           NaN            4  Deuce
# 143     1431849.0           42           NaN            5     Ad
# 144           NaN           43           NaN            1  Deuce
# 145           NaN           43           NaN            2  Deuce
# 146           NaN           43           NaN            3     Ad
# 147           NaN           43           NaN            4     Ad
# 148           NaN           43           NaN            5     Ad
# 149           NaN           43           NaN            6     Ad
# 150           NaN           43           NaN            7  Deuce
# 151           NaN           43           NaN            8  Deuce
# 152           NaN           43           NaN            9  Deuce
# 153           NaN           43           NaN           10     Ad
# 154     1472099.0           43           NaN           11     Ad
# ...
# 176           NaN              NaN  Short     short
# 177           NaN              NaN    NaN      deep
# 178  1st Serve In                T    NaN      None
# 179           NaN              NaN  Short      deep
# 180           NaN              NaN  Short      deep
# 181           NaN              NaN   Deep      deep
# 182           NaN              NaN   Deep      deep
# 183           NaN              NaN  Short     short
# 184           NaN              NaN    NaN     short
# 185  1st Serve In                T    NaN      None
# 186           NaN              NaN  Short     short
# 187           NaN              NaN   Deep      deep
# 188           NaN              NaN  Short     short
# 189           NaN              NaN   Deep      deep
# 190           NaN              NaN  Short      deep
# 191           NaN              NaN    NaN      long
# 192  1st Serve In                T    NaN      None
# 193           NaN              NaN  Short      deep
# 194           NaN              NaN   Deep      deep
# 195           NaN              NaN   Deep      deep
# 196           NaN              NaN   Deep      deep
# 197           NaN              NaN   Deep      deep
# 198           NaN              NaN   Deep      deep
# 199           NaN              NaN  Short      deep
# 200           NaN              NaN  Short     short
# 201           NaN              NaN  Short     short
# 202  2nd Serve In                T    NaN      None
# 203           NaN              NaN  Short      deep
# 204           NaN              NaN  Short      deep
# 205           NaN              NaN  Short     short
# 206  2nd Serve In             Body    NaN      None
# 207           NaN              NaN    NaN     short
# 208  2nd Serve In             Body    NaN      None
# 209           NaN              NaN  Short      deep
# 210           NaN              NaN  Short      deep
# 211           NaN              NaN    NaN     short
# 212  2nd Serve In                T    NaN      None
# 213           NaN              NaN  Short      deep
# 214           NaN              NaN   Deep      deep
# 215           NaN              NaN  Short      deep
# 216           NaN              NaN  Short     short
# 217           NaN              NaN    NaN      long
# 218  1st Serve In             Wide    NaN      None
# 219           NaN              NaN  Short      deep
# 220           NaN              NaN    NaN     short
# 221  Double Fault             Wide    NaN      None
# 222           NaN              NaN  Short      deep
# 223           NaN              NaN   Deep      deep
# 224           NaN              NaN  Short      deep
# 225           NaN              NaN    NaN      long
# 226           NaN              NaN  Short      deep
# 227           NaN              NaN    NaN     short
# 228  Double Fault             Body    NaN      None
# 229           NaN              NaN    NaN     short
# 230  1st Serve In                T    NaN      None
# 231           NaN              NaN  Short      deep
# 232           NaN              NaN   Deep      deep
# 233           NaN              NaN  Short      deep
# 234           NaN              NaN    NaN     short
# 235  Double Fault                T    NaN      None
# 236  1st Serve In                T    NaN      None
# 237           NaN              NaN  Short      deep
# 238  1st Serve In             Wide    NaN      None
# 239           NaN              NaN  Short      deep
# 240  1st Serve In             Body    NaN      None
# 241           NaN              NaN  Short      deep
# 242           NaN              NaN    NaN      long
# 243           NaN              NaN  Short      deep
# 244  1st Serve In             Wide    NaN      None
# 245           NaN              NaN   Deep      deep
# 246           NaN              NaN   Deep      deep
# 247           NaN              NaN  Short     short
# 248           NaN              NaN  Short     short
# 249           NaN              NaN   Deep      deep
# 250           NaN              NaN    NaN      deep
# 251  1st Serve In                T    NaN      None
# 252           NaN              NaN   Deep      deep
# 253           NaN              NaN   Long      deep
# 254  2nd Serve In             Body    NaN      None
# 255           NaN              NaN  Short     short
# 256           NaN              NaN  Short      deep
# 257           NaN              NaN  Short      deep
# 258           NaN              NaN  Short      deep
# 259           NaN              NaN  Short     short
# 260           NaN              NaN  Short      deep
# 261           NaN              NaN   Deep      deep
# 262           NaN              NaN  Short     short
# 263           NaN              NaN  Short      deep
# 264           NaN              NaN    NaN     short
# 265  1st Serve In             Wide    NaN      None
# 266           NaN              NaN  Short      deep
# 267  2nd Serve In             Body    NaN      None
# 268           NaN              NaN   Deep      deep
# 269           NaN              NaN  Short      deep
# 270           NaN              NaN  Short     short
# 271           NaN              NaN    NaN     short
# 272  1st Serve In             Wide    NaN      None
# 273           NaN              NaN  Short      deep
# 274           NaN              NaN   Deep      deep
# 275           NaN              NaN  Short     short
# 276           NaN              NaN  Short      deep
# 277  1st Serve In             Body    NaN      None
# 278           NaN              NaN   Deep      deep
# 279           NaN              NaN  Short      deep
# 280           NaN              NaN  Short      deep
# 281           NaN              NaN  Short      deep
# 282           NaN              NaN  Short      deep
# 283           NaN              NaN  Short      deep
# 284           NaN              NaN  Short     short
# 285           NaN              NaN  Short      deep
# 286           NaN              NaN  Short      deep
# 287           NaN              NaN  Short      deep
# 288           NaN              NaN  Short      deep
# 289           NaN              NaN  Short      deep
# 290           NaN              NaN    NaN     short
# 291  1st Serve In             Body    NaN      None
# 292           NaN              NaN  Short     short
# 293           NaN              NaN   Deep      deep
# 294           NaN              NaN    NaN     short
# 295  Double Fault             Wide    NaN      None
# 296           NaN              NaN  Short     short
# 297           NaN              NaN    NaN      deep
# 298           NaN              NaN  Short      deep
# 299  1st Serve In             Wide    NaN      None
# 300           NaN              NaN  Short      deep
# 301           NaN              NaN    NaN      long
# 302           NaN              NaN   Long      deep
# 303  2nd Serve In             Body    NaN      None
# 304           NaN              NaN   Deep      deep
# 305           NaN              NaN    NaN      long
# 306  1st Serve In             Body    NaN      None
# 307           NaN              NaN  Short      deep
# 308           NaN              NaN   Long      deep
# 309  2nd Serve In                T    NaN      None
# 310           NaN              NaN  Short      deep
# 311           NaN              NaN   Long      deep
# 312  1st Serve In             Wide    NaN      None
# 313           NaN              NaN   Deep      deep
# 314           NaN              NaN    NaN      deep
# 315           NaN              NaN  Short      deep
# 316           NaN              NaN   Deep      deep
# 317           NaN              NaN  Short     short
# 318           NaN              NaN    NaN     short
# 319  1st Serve In             Wide    NaN      None
# 320  2nd Serve In             Body    NaN      None
# 321           NaN              NaN   Long      deep
# 322  2nd Serve In             Body    NaN      None
# 323           NaN              NaN    NaN     short
# 324  2nd Serve In             Wide    NaN      None
# 325           NaN              NaN  Short     short
# 326           NaN              NaN   Long      deep
# 327  2nd Serve In                T    NaN      None
# 328           NaN              NaN    NaN      deep
# 329           NaN              NaN  Short     short
# 330           NaN              NaN  Short     short
# 331           NaN              NaN   Deep      deep
# 332           NaN              NaN  Short      deep
# 333           NaN              NaN   Deep      deep
# 334           NaN              NaN  Short     short
# 335           NaN              NaN  Short      deep
# 336           NaN              NaN    NaN     short
# 337  1st Serve In             Wide    NaN      None
# 338           NaN              NaN   Deep      deep
# 339           NaN              NaN  Short     short
# 340  1st Serve In                T    NaN      None
# 341           NaN              NaN   Deep      deep
# 342           NaN              NaN  Short      deep
# 343           NaN              NaN  Short      deep
# 344           NaN              NaN  Short      deep
# 345           NaN              NaN    NaN      long
# 346  2nd Serve In             Wide    NaN      None
# 347           NaN              NaN   Long      deep
# 348  2nd Serve In                T    NaN      None
# 349           NaN              NaN  Short      deep
# 350           NaN              NaN  Short     short
# 351           NaN              NaN  Short      deep
# 352  1st Serve In             Wide    NaN      None
# 353           NaN              NaN    NaN      long
# 354  2nd Serve In                T    NaN      None
# 355           NaN              NaN   Deep      deep
# 356           NaN              NaN  Short      deep
# 357           NaN              NaN  Short      deep
# 358           NaN              NaN   Deep      deep
# 359  1st Serve In                T    NaN      None
# 360           NaN              NaN  Short      deep
# 361           NaN              NaN  Short      deep
# 362           NaN              NaN    NaN     short
# 363  1st Serve In                T    NaN      None
# 364           NaN              NaN    NaN      deep
# 365           NaN              NaN   Long      deep
# 366  1st Serve In                T    NaN      None
# 367           NaN              NaN   Deep      deep
# 368           NaN              NaN  Short     short
# 369           NaN              NaN   Long      deep
# 370  1st Serve In                T    NaN      None
# 371           NaN              NaN   Deep      deep
# 372           NaN              NaN  Short     short
# 373           NaN              NaN    NaN     short
# 374  Double Fault              NaN    NaN      None
# 375           NaN              NaN  Short      deep
# 376           NaN              NaN  Short      deep
# 377           NaN              NaN    NaN     short
# 378  1st Serve In             Wide    NaN      None
# 379           NaN              NaN    NaN     short
# 380  2nd Serve In                T    NaN      None
# 381           NaN              NaN   Deep      deep
# 382           NaN              NaN    NaN     short
# 383  1st Serve In             Wide    NaN      None
# 384           NaN              NaN  Short     short
# 385           NaN              NaN   Deep      deep
# 386           NaN              NaN    NaN     short
# 387  1st Serve In                T    NaN      None
# 388           NaN              NaN   Deep      deep
# 389           NaN              NaN  Short     short
# 390           NaN              NaN  Short      deep
# 391           NaN              NaN    NaN     short
# 392  1st Serve In             Wide    NaN      None
# 393           NaN              NaN  Short      deep
# 394           NaN              NaN    NaN     short
# 395  2nd Serve In                T    NaN      None
# 396           NaN              NaN  Short     short
# 397  1st Serve In             Wide    NaN      None
# 398           NaN              NaN   Deep      deep
# 399           NaN              NaN    NaN     short
# 400  1st Serve In             Wide    NaN      None
# 401           NaN              NaN  Short     short
# 402           NaN              NaN  Short      deep
# 403           NaN              NaN  Short     short
# 404           NaN              NaN    NaN      long
# 405  1st Serve In                T    NaN      None
# 406  1st Serve In                T    NaN      None
# 407           NaN              NaN  Short     short
# 408           NaN              NaN  Short      deep
# 409  1st Serve In             Body    NaN      None
# 410           NaN              NaN   Deep      deep
# 411           NaN              NaN  Short      deep
# 412           NaN              NaN    NaN      long
# 413  1st Serve In                T    NaN      None
# 414           NaN              NaN  Short      deep
# 415           NaN              NaN  Short      deep
# 416           NaN              NaN  Short      deep
# 417           NaN              NaN   Deep      deep
# 418           NaN              NaN  Short      deep
# 419           NaN              NaN   Deep      deep
# 420           NaN              NaN    NaN      long
# 421           NaN              NaN  Short      deep
# 422           NaN              NaN   Deep      deep
# 423           NaN              NaN    NaN     short
# 424  1st Serve In                T    NaN      None
# 425           NaN              NaN  Short     short
# 426           NaN              NaN   Deep      deep
# 427           NaN              NaN   Long      deep
# 428  1st Serve In                T    NaN      None
# 429           NaN              NaN  Short      deep
# 430  2nd Serve In             Wide    NaN      None
# 431           NaN              NaN   Long      deep
# 432  1st Serve In             Wide    NaN      None
# 433           NaN              NaN    NaN     short
# 434  Double Fault              NaN    NaN      None
# 435           NaN              NaN   Deep      deep
# 436           NaN              NaN  Short      deep
# 437           NaN              NaN    NaN     short
# 438           NaN              NaN   Deep      deep
# 439           NaN              NaN   Deep      deep
# 440           NaN              NaN  Short      deep
# 441           NaN              NaN    NaN      deep
# 442           NaN              NaN  Short      deep
# 443           NaN              NaN   Deep      deep
# 444           NaN              NaN  Short      deep
# 445           NaN              NaN  Short      deep
# 446           NaN              NaN   Deep      deep
# 447           NaN              NaN  Short      deep
# 448           NaN              NaN   Deep      deep
# 449           NaN              NaN   Deep      deep
# 450           NaN              NaN  Short      deep
# 451           NaN              NaN   Deep      deep
# 452           NaN              NaN    NaN     short
# 453  1st Serve In             Body    NaN      None
# 454           NaN              NaN  Short      deep
# 455           NaN              NaN  Short      deep
# 456           NaN              NaN    NaN     short
# 457  1st Serve In             Body    NaN      None
# 458           NaN              NaN  Short      deep
# 459           NaN              NaN   Deep      deep
# 460           NaN              NaN   Deep      deep
# 461           NaN              NaN  Short     short
# 462  1st Serve In                T    NaN      None
# 463           NaN              NaN  Short      deep
# 464           NaN              NaN  Short      deep
# 465           NaN              NaN  Short      deep
# 466           NaN              NaN   Long      deep
# 467  1st Serve In             Body    NaN      None
# 468           NaN              NaN  Short     short
# 469           NaN              NaN  Short     short
# 470           NaN              NaN    NaN     short
# 471  1st Serve In                T    NaN      None
