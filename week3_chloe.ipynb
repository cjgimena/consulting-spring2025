# %% [markdown]
# ## Week 3: Jupyter Notebook - Pandas GroupBy, Apply, and Create Your Own Functions
# Make sure to select your Kernel before starting!

# %% [markdown]
# ### Import Pandas Library/Package
# `import pandas as pd`

# %%
import pandas as pd

# %% [markdown]
# ### Optional: Displaying your Dataframe
# Don't use for big datasets

# %%
pd.set_option("display.max_columns", None)  # Show all columns
pd.set_option("display.max_rows", None)     # Show all rows

# %% [markdown]
# ### GroupBy Functions
# `df.groupby()`

# %% [markdown]
# Create own dataset

# %%
data = {
    'Name': ['Zophie', 'Alice', 'Bob', 'Charlie', 'Max', 'Milo', 'Luna', 'Bella'],
    'Age': [7, 5, 3, 2, 5, 3, 2, 5],
    'Color': ['Gray', 'Black', 'Brown', 'White', 'Black', 'Brown', 'White', 'Black'],
    'Owner': ['Charles', 'Charles', 'Cj', 'Cj', 'Cj', 'Charles', 'Cj', 'Charles'],
    'Type': ['Cat', 'Cat', 'Dog', 'Dog', 'Dog', 'Cat', 'Dog', 'Cat']
}

# Create DataFrame
df = pd.DataFrame(data)
df
# Out:
#       Name  Age  Color    Owner Type
# 0   Zophie    7   Gray  Charles  Cat
# 1    Alice    5  Black  Charles  Cat
# 2      Bob    3  Brown       Cj  Dog
# 3  Charlie    2  White       Cj  Dog
# 4      Max    5  Black       Cj  Dog
# 5     Milo    3  Brown  Charles  Cat
# 6     Luna    2  White       Cj  Dog
# 7    Bella    5  Black  Charles  Cat

# %% [markdown]
# Count how many pets of each color each owner has
#
# `.size()`

# %%
# Group By Owner and Color
df.groupby(['Owner', 'Color']).size()
# Out:
# Owner    Color
# Charles  Black    2
#          Brown    1
#          Gray     1
# Cj       Black    1
#          Brown    1
#          White    2
# dtype: int64

# %% [markdown]
# ### Read In Datasets
# `pd.read_csv()`
#
# Read in the file from the data folder called `Shot_Visuals_KaylanBigun_NathanTrouve.csv`

# %%
# Read data and create df variable
shots = pd.read_csv('data/Shot_Visuals_KaylanBigun_NathanTrouve.csv')
# Print the head of the object
shots.head()
# Out:
#   pointScore gameScore setScore  isPointStart  pointStartTime  isPointEnd  \
# 0        0-0       0-0      0-0           1.0         25020.0         NaN
# 1        0-0       0-0      0-0           NaN         36320.0         NaN
# 2        0-0       0-0      0-0           NaN         37349.0         NaN
# 3        0-0       0-0      0-0           NaN         38549.0         1.0
# 4       15-0       0-0      0-0           1.0         57814.0         1.0
#
#    pointEndTime  pointNumber  isBreakPoint  shotInRally  ...   returnerName  \
# 0           NaN            1           NaN            1  ...  Nathan Trouve
# 1           NaN            1           NaN            2  ...  Nathan Trouve
# 2           NaN            1           NaN            3  ...  Nathan Trouve
# 3       38549.0            1           NaN            4  ...  Nathan Trouve
# 4       61681.0            2           NaN            1  ...  Nathan Trouve
#
#        shotHitBy InsideOut  InsideIn isDoubleFault    pointWonBy  \
# 0   Kaylan Bigun       NaN       NaN           NaN           NaN
# 1  Nathan Trouve       1.0       NaN           NaN           NaN
# 2   Kaylan Bigun       1.0       NaN           NaN           NaN
# 3  Nathan Trouve       NaN       NaN           NaN  Kaylan Bigun
# 4   Kaylan Bigun       NaN       NaN           NaN  Kaylan Bigun
#
#    lastShotError   serveResult serveInPlacement  depth
# 0            NaN  2nd Serve In                T    NaN
# 1            NaN           NaN              NaN   Deep
# 2            NaN           NaN              NaN    NaN
# 3            1.0           NaN              NaN   Long
# 4            NaN  1st Serve In             Wide    NaN
#
# [5 rows x 72 columns]

# %% [markdown]
# ##### Create Sample dataframe
# - save as `sample_df`
# - First 3 points

# %%
# sample_df and first 3 points
sample_df = shots.head(11)
sample_df
# Out:
#    pointScore gameScore setScore  isPointStart  pointStartTime  isPointEnd  \
# 0         0-0       0-0      0-0           1.0         25020.0         NaN
# 1         0-0       0-0      0-0           NaN         36320.0         NaN
# 2         0-0       0-0      0-0           NaN         37349.0         NaN
# 3         0-0       0-0      0-0           NaN         38549.0         1.0
# 4        15-0       0-0      0-0           1.0         57814.0         1.0
# 5        30-0       0-0      0-0           1.0         61671.0         NaN
# 6        30-0       0-0      0-0           NaN         81681.0         NaN
# 7        30-0       0-0      0-0           NaN         82877.0         NaN
# 8        30-0       0-0      0-0           NaN         84155.0         NaN
# 9        30-0       0-0      0-0           NaN         85964.0         NaN
# 10       30-0       0-0      0-0           NaN         87340.0         1.0
#
#     pointEndTime  pointNumber  isBreakPoint  shotInRally  ...   returnerName  \
# 0            NaN            1           NaN            1  ...  Nathan Trouve
# 1            NaN            1           NaN            2  ...  Nathan Trouve
# 2            NaN            1           NaN            3  ...  Nathan Trouve
# 3        38549.0            1           NaN            4  ...  Nathan Trouve
# 4        61681.0            2           NaN            1  ...  Nathan Trouve
# 5            NaN            3           NaN            1  ...  Nathan Trouve
# 6            NaN            3           NaN            2  ...  Nathan Trouve
# 7            NaN            3           NaN            3  ...  Nathan Trouve
# 8            NaN            3           NaN            4  ...  Nathan Trouve
# 9            NaN            3           NaN            5  ...  Nathan Trouve
# 10       90130.0            3           NaN            6  ...  Nathan Trouve
#
#         shotHitBy InsideOut  InsideIn isDoubleFault    pointWonBy  \
# 0    Kaylan Bigun       NaN       NaN           NaN           NaN
# 1   Nathan Trouve       1.0       NaN           NaN           NaN
# 2    Kaylan Bigun       1.0       NaN           NaN           NaN
# 3   Nathan Trouve       NaN       NaN           NaN  Kaylan Bigun
# 4    Kaylan Bigun       NaN       NaN           NaN  Kaylan Bigun
# 5    Kaylan Bigun       NaN       NaN           NaN           NaN
# 6   Nathan Trouve       NaN       1.0           NaN           NaN
# 7    Kaylan Bigun       NaN       1.0           NaN           NaN
# 8   Nathan Trouve       NaN       NaN           NaN           NaN
# 9    Kaylan Bigun       NaN       NaN           NaN           NaN
# 10  Nathan Trouve       NaN       NaN           NaN  Kaylan Bigun
#
#     lastShotError   serveResult serveInPlacement  depth
# 0             NaN  2nd Serve In                T    NaN
# 1             NaN           NaN              NaN   Deep
# 2             NaN           NaN              NaN    NaN
# 3             1.0           NaN              NaN   Long
# 4             NaN  1st Serve In             Wide    NaN
# 5             NaN  1st Serve In                T    NaN
# 6             NaN           NaN              NaN  Short
# 7             NaN           NaN              NaN  Short
# 8             NaN           NaN              NaN  Short
# 9             NaN           NaN              NaN  Short
# 10            1.0           NaN              NaN   Long
#
# [11 rows x 72 columns]

# %% [markdown]
# Group By `pointNumber` and subset the columns `pointStartTime`
#
# Use the `.first()` function to grab the first value

# %%
sample_df.groupby('pointNumber')['pointStartTime'].first()
# Out:
# pointNumber
# 1    25020.0
# 2    57814.0
# 3    61671.0
# Name: pointStartTime, dtype: float64

# %% [markdown]
# Use the `.last()` function to grab the last value

# %%
sample_df.groupby('pointNumber')['pointStartTime'].last()
# Out:
# pointNumber
# 1    38549.0
# 2    57814.0
# 3    87340.0
# Name: pointStartTime, dtype: float64

# %% [markdown]
# ### Create your own functions
#
# `def function()`

# %%
# set a variable x = 2
x = 2
# print variable x
x
# Out:
# 2

# %%
# Create a function that takes a variable x and returns x + 1
def function(x):
    answer = x + 1
    return answer

# %%
function(4)
# Out:
# 5

# %% [markdown]
# ##### Personalize your function name and add multiple arguments

# %%
# Create a function that takes a variable x and returns x + 2
def add_two(x):
    answer = x + 2
    return answer

# %%
# print function and arguments
add_two(6)
# Out:
# 8

# %% [markdown]
# ### Apply Functions
# `.apply()`

# %%
# Use the pets dataset for this example
df
# Out:
#       Name  Age  Color    Owner Type
# 0   Zophie    7   Gray  Charles  Cat
# 1    Alice    5  Black  Charles  Cat
# 2      Bob    3  Brown       Cj  Dog
# 3  Charlie    2  White       Cj  Dog
# 4      Max    5  Black       Cj  Dog
# 5     Milo    3  Brown  Charles  Cat
# 6     Luna    2  White       Cj  Dog
# 7    Bella    5  Black  Charles  Cat

# %%
# Add 1 to the Age column of the pets dataset
df['Age'] = df['Age'].apply(lambda x: x + 1)
df['Age']
# Out:
# 0    9
# 1    7
# 2    5
# 3    4
# 4    7
# 5    5
# 6    4
# 7    7
# Name: Age, dtype: int64

# %%
# same as creating your own function
def function(x):
    answer = x * 10 
    return answer

df['Age'] = df['Age'].apply(function)
df['Age']
# Out:
# 0    90
# 1    70
# 2    50
# 3    40
# 4    70
# 5    50
# 6    40
# 7    70
# Name: Age, dtype: int64

# %%
# Also use the summarizing functions (mean, max, mean)
df['Age'].apply('mean')
# Out:
# 60.0

# %%
df['Age'].apply('max')
# Out:
# 90

# %%
# But the same as this
df['Age'] + 1
# Out:
# 0    91
# 1    71
# 2    51
# 3    41
# 4    71
# 5    51
# 6    41
# 7    71
# Name: Age, dtype: int64

# %% [markdown]
# But if you notice this code below gives us the same as our `plus_one()` function

# %% [markdown]
# Use case is in the conditional statements!!

# %%
# create a function that classifies 5 years and younger as 'young' and everything above 'old'
def classify_age(age):
    if age <= 5:
        return 'young'
    else:
        return 'old'
    
df['life_stage'] = df['Age'].apply(classify_age)
df
# Out:
#       Name  Age  Color    Owner Type life_stage
# 0   Zophie   90   Gray  Charles  Cat        old
# 1    Alice   70  Black  Charles  Cat        old
# 2      Bob   50  Brown       Cj  Dog        old
# 3  Charlie   40  White       Cj  Dog        old
# 4      Max   70  Black       Cj  Dog        old
# 5     Milo   50  Brown  Charles  Cat        old
# 6     Luna   40  White       Cj  Dog        old
# 7    Bella   70  Black  Charles  Cat        old

# %% [markdown]
# Create a new Column called duration in `new_df`
# - using the apply function **row-rise**

# %%
# new_df
new_df = sample_df.groupby('pointNumber')[['pointStartTime']].first()
new_df
# Out:
#              pointStartTime
# pointNumber
# 1                   25020.0
# 2                   57814.0
# 3                   61671.0

# %%
new_df['pointEndTime'] = sample_df.groupby('pointNumber')[['pointEndTime']].last()
new_df
# Out:
#              pointStartTime  pointEndTime
# pointNumber
# 1                   25020.0       38549.0
# 2                   57814.0       61681.0
# 3                   61671.0       90130.0

# %%
def duration(end, start):
    duration = end - start
    return duration

new_df['duration'] = new_df.apply(lambda x: duration(x['pointEndTime'], x['pointStartTime']), axis = 1)
new_df
# Out:
#              pointStartTime  pointEndTime  duration
# pointNumber
# 1                   25020.0       38549.0   13529.0
# 2                   57814.0       61681.0    3867.0
# 3                   61671.0       90130.0   28459.0

# %% [markdown]
# But as you notice this function could be simplified to...

# %%
new_df['duration2'] = new_df['pointEndTime'] - new_df['pointStartTime']
new_df
# Out:
#              pointStartTime  pointEndTime  duration  duration2
# pointNumber
# 1                   25020.0       38549.0   13529.0    13529.0
# 2                   57814.0       61681.0    3867.0     3867.0
# 3                   61671.0       90130.0   28459.0    28459.0

# %% [markdown]
# Use case is in the conditional statements!!

# %% [markdown]
# ### Problems to Practice Yourself!!
#
# #### Problem 1: From the `(playsight)kaylan_usc.xlsx` dataset, classify the speed of the ball
# - More than 110: **Fast**
# - Less than 110 and greater than 70: **Regular**
# - Less than 70: **Slow**

# %%
import pandas as pd

shots_excel = pd.read_excel('data/(playsight)kaylan_usc.xlsx', sheet_name='Shots')
shots_excel.head()

def classify_speed(speed):
    if speed > 110:
        return "fast"
    elif speed > 70:
        return "regular"
    else:
        return "slow"
    
shots_excel['ClassifiedSpeed'] = shots_excel['Speed (MPH)'].apply(classify_speed)
shots_excel
# Out:
#             Player  Shot             Type    Stroke     Spin  Speed (MPH)  \
# 0     Kaylan Bigun     1      first_serve     Serve    Slice    86.335464
# 1    Nathan Trouve     1             none  Backhand     Flat    35.898598
# 2     Kaylan Bigun     1     second_serve     Serve    Slice    81.066826
# 3    Nathan Trouve     2    second_return  Backhand     Flat    61.041412
# 4     Kaylan Bigun     3   serve_plus_one  Forehand  Topspin    62.817978
# ..             ...   ...              ...       ...      ...          ...
# 539  Nathan Trouve     1      first_serve     Serve     Flat   108.220818
# 540   Kaylan Bigun     2     first_return  Forehand  Topspin    36.660290
# 541  Nathan Trouve     3   serve_plus_one  Backhand    Slice    42.250107
# 542  Nathan Trouve     4  return_plus_one  Overhead     Flat    60.578091
# 543  Nathan Trouve     1      first_serve     Serve     Flat    37.595879
#
#      Point  Game  Set Bounce Depth  ... Hit Side   Hit (x)    Hit (y)  \
# 0        1     1    1         deep  ...     near  0.978027   0.181941
# 1        1     1    1         deep  ...      far -0.909668  24.365038
# 2        1     1    1        short  ...     near  0.976562   0.518099
# 3        1     1    1         deep  ...      far -1.298828  23.865038
# 4        1     1    1          out  ...     near  0.910156  -0.470559
# ..     ...   ...  ...          ...  ...      ...       ...        ...
# 539    115    20    2        short  ...      far  1.132812  22.286913
# 540    115    20    2        short  ...     near -3.189453   0.545066
# 541    115    20    2        short  ...      far  2.984375  23.365038
# 542    115    20    2        short  ...      far  2.121094  17.849413
# 543    116    20    2        short  ...      far  0.179565  23.632326
#
#       Hit (z)      Direction Result Favorited  Start Time   Video Time  \
# 0    2.421875     down the T    Out     False    22:45:24    25.020000
# 1    1.114258      inside in     In     False    22:45:25    26.020000
# 2    2.332031     down the T     In     False    22:45:34    35.220001
# 3    0.971680     inside out     In     False    22:45:35    36.320000
# 4    0.833008     inside out    Out     False    22:45:36    37.349998
# ..        ...            ...    ...       ...         ...          ...
# 539  2.345703     down the T     In     False    23:58:52  4433.919922
# 540  1.249023    cross court     In     False    23:58:53  4434.580078
# 541  0.604004  down the line     In     False    23:58:55  4436.419922
# 542  2.363281            ---     In     False    23:58:58  4439.640137
# 543  2.226562     down the T     In     False    23:59:16  4457.669922
#
#      ClassifiedSpeed
# 0            regular
# 1               slow
# 2            regular
# 3               slow
# 4               slow
# ..               ...
# 539          regular
# 540             slow
# 541             slow
# 542             slow
# 543             slow
#
# [544 rows x 26 columns]

# %% [markdown]
# #### Problem 2: From the `Shot_Visuals_KaylanBigun_NathanTrouve.csv` dataset, create a new column called "shot_depth"
# - Use the image below to classify shots as deep, short, and long
# - Create a function that takes the arguments `shotLocationX` and `shotLocationY` to create the outputs **short**, **deep**, and **long**

# %%
from IPython.display import Image

Image(filename='images/court_dimensions.jpg', width=250)

# IN RELATION TO THIS DATASET'S COORDINATES

# Origin is at the center of the court
# 455 is the top of the court, -455 is the bottom of the court
# -210 is the left side of the court, 210 is the right side of the court

# %%
# read in the dataset
shots = pd.read_csv('data/Shot_Visuals_KaylanBigun_NathanTrouve.csv')
shots.head()
# Out:
#   pointScore gameScore setScore  isPointStart  pointStartTime  isPointEnd  \
# 0        0-0       0-0      0-0           1.0         25020.0         NaN
# 1        0-0       0-0      0-0           NaN         36320.0         NaN
# 2        0-0       0-0      0-0           NaN         37349.0         NaN
# 3        0-0       0-0      0-0           NaN         38549.0         1.0
# 4       15-0       0-0      0-0           1.0         57814.0         1.0
#
#    pointEndTime  pointNumber  isBreakPoint  shotInRally  ...   returnerName  \
# 0           NaN            1           NaN            1  ...  Nathan Trouve
# 1           NaN            1           NaN            2  ...  Nathan Trouve
# 2           NaN            1           NaN            3  ...  Nathan Trouve
# 3       38549.0            1           NaN            4  ...  Nathan Trouve
# 4       61681.0            2           NaN            1  ...  Nathan Trouve
#
#        shotHitBy InsideOut  InsideIn isDoubleFault    pointWonBy  \
# 0   Kaylan Bigun       NaN       NaN           NaN           NaN
# 1  Nathan Trouve       1.0       NaN           NaN           NaN
# 2   Kaylan Bigun       1.0       NaN           NaN           NaN
# 3  Nathan Trouve       NaN       NaN           NaN  Kaylan Bigun
# 4   Kaylan Bigun       NaN       NaN           NaN  Kaylan Bigun
#
#    lastShotError   serveResult serveInPlacement  depth
# 0            NaN  2nd Serve In                T    NaN
# 1            NaN           NaN              NaN   Deep
# 2            NaN           NaN              NaN    NaN
# 3            1.0           NaN              NaN   Long
# 4            NaN  1st Serve In             Wide    NaN
#
# [5 rows x 72 columns]

# %%
# create function
def classify_shot_depth(shotLocationX, shotLocationY):
    
    if abs(shotLocationX) > 157.5:
        return 'long'

    y_abs = abs(shotLocationY)

    if y_abs <= 157.5:
        return 'short'
    elif y_abs <= 242:
        return 'deep'
    else:
        return 'long'

# %%
# apply function
shots['ShotDepth'] = shots.apply(lambda x: classify_shot_depth(x['shotLocationX'], x['shotLocationY']), axis = 1)
shots.head()
# Out:
#   pointScore gameScore setScore  isPointStart  pointStartTime  isPointEnd  \
# 0        0-0       0-0      0-0           1.0         25020.0         NaN
# 1        0-0       0-0      0-0           NaN         36320.0         NaN
# 2        0-0       0-0      0-0           NaN         37349.0         NaN
# 3        0-0       0-0      0-0           NaN         38549.0         1.0
# 4       15-0       0-0      0-0           1.0         57814.0         1.0
#
#    pointEndTime  pointNumber  isBreakPoint  shotInRally  ...      shotHitBy  \
# 0           NaN            1           NaN            1  ...   Kaylan Bigun
# 1           NaN            1           NaN            2  ...  Nathan Trouve
# 2           NaN            1           NaN            3  ...   Kaylan Bigun
# 3       38549.0            1           NaN            4  ...  Nathan Trouve
# 4       61681.0            2           NaN            1  ...   Kaylan Bigun
#
#   InsideOut InsideIn  isDoubleFault    pointWonBy  lastShotError  \
# 0       NaN      NaN            NaN           NaN            NaN
# 1       1.0      NaN            NaN           NaN            NaN
# 2       1.0      NaN            NaN           NaN            NaN
# 3       NaN      NaN            NaN  Kaylan Bigun            1.0
# 4       NaN      NaN            NaN  Kaylan Bigun            NaN
#
#     serveResult  serveInPlacement depth  ShotDepth
# 0  2nd Serve In                 T   NaN       long
# 1           NaN               NaN  Deep       long
# 2           NaN               NaN   NaN       long
# 3           NaN               NaN  Long       long
# 4  1st Serve In              Wide   NaN       long
#
# [5 rows x 73 columns]
